# %% [markdown]
# # 🚀 Create Your First AI Agent - Travel Planning Assistant (Python)
#
# ## 📋 Tutorial Overview
#
# Welcome to your first hands-on experience building an AI agent with the Microsoft Agent Framework! This tutorial will guide you through creating a sophisticated travel planning assistant that can automatically generate personalized vacation itineraries using GitHub Models.
#
# **What You'll Build:**
# - 🎯 **Smart Travel Agent**: An AI assistant that plans detailed day trips
# - 🎲 **Random Destination Tool**: Custom function for inspiring destination suggestions
# - 🤖 **Conversational Interface**: Natural language interaction with advanced AI capabilities
# - 🔧 **Tool Integration**: Learn how agents use functions to extend their capabilities
#
# ## 🎯 Learning Objectives
#
# By completing this tutorial, you will understand:
#
# ### 🏗️ **Agent Architecture Fundamentals**
# - How to structure AI agents using the Microsoft Agent Framework
# - The relationship between agents, tools, and language models
# - Best practices for agent configuration and deployment
#
# ### 🛠️ **Tool Integration Patterns**
# - Creating custom functions that agents can call dynamically
# - Understanding function calling in large language models
# - Designing tools for optimal agent performance
#
# ### 🔗 **API Integration Strategies**
# - Connecting to GitHub Models for enterprise-grade AI inference
# - Managing API credentials and configuration securely
# - Handling asynchronous operations in agent workflows
#
# ### 💡 **Conversation Management**
# - Building natural, contextual conversations with AI agents
# - Managing conversation state and memory
# - Implementing effective agent instructions and personality
#
# ## ⚙️ Prerequisites & Environment Setup
#
# ### 📦 **Required Dependencies**
#
# First, ensure you have the latest Agent Framework installed:
#
# ```bash
# pip install agent-framework-core -U
# ```
#
# ### 🔑 **GitHub Models Configuration**
#
# You'll need access to GitHub Models (currently in preview):
#
# 1. **Sign up for GitHub Models**: Visit [GitHub Models](https://github.com/marketplace/models) and request access
# 2. **Generate Personal Access Token**: Create a token with model access permissions
# 3. **Configure Environment Variables**: Create a `.env` file in your project root:
#
# ```env
# # GitHub Models API Configuration
# GITHUB_TOKEN=your_github_personal_access_token_here
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ### 🏢 **Enterprise Considerations**
#
# - **Security**: Store API keys in environment variables, never in source code
# - **Rate Limits**: GitHub Models has usage quotas; monitor your consumption
# - **Model Selection**: Choose appropriate models based on your use case and budget
# - **Error Handling**: Implement robust error handling for production deployments
#
# ## 🎨 Design Pattern: Function-Calling Agents
#
# This tutorial demonstrates the **Function-Calling Agent** pattern, where:
#
# ```mermaid
# graph LR
#     A[User Request] --> B[Agent Analysis]
#     B --> C{Need Tools?}
#     C -->|Yes| D[Call Function]
#     C -->|No| E[Direct Response]
#     D --> F[Process Results]
#     F --> E
#     E --> G[Final Response]
# ```
#
# **Key Benefits:**
# - 🎯 **Deterministic Actions**: Tools provide reliable, predictable functionality
# - 🔧 **Extensibility**: Easy to add new capabilities without retraining
# - 🏢 **Enterprise Ready**: Integrate with existing systems and databases
# - 📊 **Observability**: Clear tracking of agent decisions and tool usage
#
# ## 🌟 Next Steps
#
# After completing this tutorial, explore:
# - **Advanced Tool Patterns**: Database queries, API integrations, file operations
# - **Multi-Agent Systems**: Coordinating multiple specialized agents
# - **RAG Integration**: Adding knowledge retrieval capabilities
# - **Production Deployment**: Scaling agents for enterprise use
#
# Let's build your first AI agent! 🚀

# %%
! pip install -r ../../../Installation/requirements.txt -U
# Out:
# Collecting agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core (from -r ../../../Installation/requirements.txt (line 1))
#   Cloning https://github.com/microsoft/agent-framework.git (to revision main) to /private/var/folders/66/m82q566n4c130x_vdtybj5b40000gn/T/pip-install-dkc078x2/agent-framework-core_748f9b90d1d4492da6e7441a66c7b545
#   Running command git clone --filter=blob:none --quiet https://github.com/microsoft/agent-framework.git /private/var/folders/66/m82q566n4c130x_vdtybj5b40000gn/T/pip-install-dkc078x2/agent-framework-core_748f9b90d1d4492da6e7441a66c7b545
#   Resolved https://github.com/microsoft/agent-framework.git to commit 6d7690e485083063c4026c78d65efa07aacea5cc
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting agent-framework-azure-ai@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/azure-ai (from -r ../../../Installation/requirements.txt (line 2))
#   Cloning https://github.com/microsoft/agent-framework.git (to revision main) to /private/var/folders/66/m82q566n4c130x_vdtybj5b40000gn/T/pip-install-dkc078x2/agent-framework-azure-ai_e6562bdb57924ebbbe5ae742fbe8d078
#   Running command git clone --filter=blob:none --quiet https://github.com/microsoft/agent-framework.git /private/var/folders/66/m82q566n4c130x_vdtybj5b40000gn/T/pip-install-dkc078x2/agent-framework-azure-ai_e6562bdb57924ebbbe5ae742fbe8d078
#   Resolved https://github.com/microsoft/agent-framework.git to commit 6d7690e485083063c4026c78d65efa07aacea5cc
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting agent-framework-devui@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/devui (from -r ../../../Installation/requirements.txt (line 3))
#   Cloning https://github.com/microsoft/agent-framework.git (to revision main) to /private/var/folders/66/m82q566n4c130x_vdtybj5b40000gn/T/pip-install-dkc078x2/agent-framework-devui_9297a4c676324c61b7624241e82ba23a
#   Running command git clone --filter=blob:none --quiet https://github.com/microsoft/agent-framework.git /private/var/folders/66/m82q566n4c130x_vdtybj5b40000gn/T/pip-install-dkc078x2/agent-framework-devui_9297a4c676324c61b7624241e82ba23a
#   Resolved https://github.com/microsoft/agent-framework.git to commit 6d7690e485083063c4026c78d65efa07aacea5cc
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting agent-framework-ag-ui@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/ag-ui (from -r ../../../Installation/requirements.txt (line 4))
#   Cloning https://github.com/microsoft/agent-framework.git (to revision main) to /private/var/folders/66/m82q566n4c130x_vdtybj5b40000gn/T/pip-install-dkc078x2/agent-framework-ag-ui_70ce1032feea495a8b1829e5b978a099
#   Running command git clone --filter=blob:none --quiet https://github.com/microsoft/agent-framework.git /private/var/folders/66/m82q566n4c130x_vdtybj5b40000gn/T/pip-install-dkc078x2/agent-framework-ag-ui_70ce1032feea495a8b1829e5b978a099
#   Resolved https://github.com/microsoft/agent-framework.git to commit 6d7690e485083063c4026c78d65efa07aacea5cc
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting agent-framework-anthropic@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/anthropic (from -r ../../../Installation/requirements.txt (line 5))
#   Cloning https://github.com/microsoft/agent-framework.git (to revision main) to /private/var/folders/66/m82q566n4c130x_vdtybj5b40000gn/T/pip-install-dkc078x2/agent-framework-anthropic_84d91128f97048ebb2521687374565ff
#   Running command git clone --filter=blob:none --quiet https://github.com/microsoft/agent-framework.git /private/var/folders/66/m82q566n4c130x_vdtybj5b40000gn/T/pip-install-dkc078x2/agent-framework-anthropic_84d91128f97048ebb2521687374565ff
#   Resolved https://github.com/microsoft/agent-framework.git to commit 6d7690e485083063c4026c78d65efa07aacea5cc
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting agent-framework-ollama@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/ollama (from -r ../../../Installation/requirements.txt (line 6))
#   Cloning https://github.com/microsoft/agent-framework.git (to revision main) to /private/var/folders/66/m82q566n4c130x_vdtybj5b40000gn/T/pip-install-dkc078x2/agent-framework-ollama_acb745656f8f40daa90f57a21ee89e0b
#   Running command git clone --filter=blob:none --quiet https://github.com/microsoft/agent-framework.git /private/var/folders/66/m82q566n4c130x_vdtybj5b40000gn/T/pip-install-dkc078x2/agent-framework-ollama_acb745656f8f40daa90f57a21ee89e0b
#   Resolved https://github.com/microsoft/agent-framework.git to commit 6d7690e485083063c4026c78d65efa07aacea5cc
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing-extensions in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: pydantic<3,>=2 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (2.12.5)
# Requirement already satisfied: pydantic-settings<3,>=2 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (2.12.0)
# Requirement already satisfied: opentelemetry-api>=1.39.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.39.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (0.4.13)
# Requirement already satisfied: openai>=1.99.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (2.15.0)
# Requirement already satisfied: azure-identity<2,>=1 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (1.25.1)
# Requirement already satisfied: mcp<2,>=1.24.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (1.25.0)
# Requirement already satisfied: packaging>=24.1 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (25.0)
# Requirement already satisfied: azure-ai-projects>=2.0.0b2 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from agent-framework-azure-ai@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/azure-ai->-r ../../../Installation/requirements.txt (line 2)) (2.0.0b3)
# Requirement already satisfied: azure-ai-agents==1.2.0b5 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from agent-framework-azure-ai@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/azure-ai->-r ../../../Installation/requirements.txt (line 2)) (1.2.0b5)
# Requirement already satisfied: aiohttp in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from agent-framework-azure-ai@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/azure-ai->-r ../../../Installation/requirements.txt (line 2)) (3.13.3)
# Requirement already satisfied: fastapi>=0.104.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from agent-framework-devui@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/devui->-r ../../../Installation/requirements.txt (line 3)) (0.128.0)
# Requirement already satisfied: uvicorn>=0.24.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/devui->-r ../../../Installation/requirements.txt (line 3)) (0.40.0)
# Requirement already satisfied: python-dotenv>=1.0.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from agent-framework-devui@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/devui->-r ../../../Installation/requirements.txt (line 3)) (1.2.1)
# Requirement already satisfied: ag-ui-protocol>=0.1.9 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from agent-framework-ag-ui@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/ag-ui->-r ../../../Installation/requirements.txt (line 4)) (0.1.10)
# Requirement already satisfied: anthropic<1,>=0.70.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from agent-framework-anthropic@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/anthropic->-r ../../../Installation/requirements.txt (line 5)) (0.76.0)
# Requirement already satisfied: ollama>=0.5.3 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from agent-framework-ollama@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/ollama->-r ../../../Installation/requirements.txt (line 6)) (0.6.1)
# Requirement already satisfied: isodate>=0.6.1 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/azure-ai->-r ../../../Installation/requirements.txt (line 2)) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/azure-ai->-r ../../../Installation/requirements.txt (line 2)) (1.38.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from anthropic<1,>=0.70.0->agent-framework-anthropic@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/anthropic->-r ../../../Installation/requirements.txt (line 5)) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from anthropic<1,>=0.70.0->agent-framework-anthropic@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/anthropic->-r ../../../Installation/requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from anthropic<1,>=0.70.0->agent-framework-anthropic@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/anthropic->-r ../../../Installation/requirements.txt (line 5)) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from anthropic<1,>=0.70.0->agent-framework-anthropic@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/anthropic->-r ../../../Installation/requirements.txt (line 5)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from anthropic<1,>=0.70.0->agent-framework-anthropic@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/anthropic->-r ../../../Installation/requirements.txt (line 5)) (0.12.0)
# Requirement already satisfied: sniffio in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from anthropic<1,>=0.70.0->agent-framework-anthropic@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/anthropic->-r ../../../Installation/requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from anyio<5,>=3.5.0->anthropic<1,>=0.70.0->agent-framework-anthropic@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/anthropic->-r ../../../Installation/requirements.txt (line 5)) (3.11)
# Requirement already satisfied: cryptography>=2.5 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: certifi in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from httpx<1,>=0.25.0->anthropic<1,>=0.70.0->agent-framework-anthropic@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/anthropic->-r ../../../Installation/requirements.txt (line 5)) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from httpx<1,>=0.25.0->anthropic<1,>=0.70.0->agent-framework-anthropic@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/anthropic->-r ../../../Installation/requirements.txt (line 5)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic<1,>=0.70.0->agent-framework-anthropic@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/anthropic->-r ../../../Installation/requirements.txt (line 5)) (0.16.0)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (4.26.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (0.0.21)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: starlette>=0.27 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (0.50.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: websockets>=15.0.1 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from pydantic<3,>=2->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from pydantic<3,>=2->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (2.41.5)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from azure-ai-projects>=2.0.0b2->agent-framework-azure-ai@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/azure-ai->-r ../../../Installation/requirements.txt (line 2)) (12.28.0)
# Requirement already satisfied: requests>=2.21.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/azure-ai->-r ../../../Installation/requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pycparser in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (2.23)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from fastapi>=0.104.0->agent-framework-devui@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/devui->-r ../../../Installation/requirements.txt (line 3)) (0.0.4)
# Requirement already satisfied: attrs>=22.2.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/azure-ai->-r ../../../Installation/requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/azure-ai->-r ../../../Installation/requirements.txt (line 2)) (2.6.3)
# Requirement already satisfied: tqdm>4 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from opentelemetry-api>=1.39.0->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.39.0->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from opentelemetry-sdk>=1.39.0->agent-framework-core@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/core->-r ../../../Installation/requirements.txt (line 1)) (0.60b1)
# Requirement already satisfied: click>=7.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from uvicorn>=0.24.0->uvicorn[standard]>=0.24.0->agent-framework-devui@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/devui->-r ../../../Installation/requirements.txt (line 3)) (8.3.1)
# Requirement already satisfied: httptools>=0.6.3 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/devui->-r ../../../Installation/requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/devui->-r ../../../Installation/requirements.txt (line 3)) (6.0.3)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/devui->-r ../../../Installation/requirements.txt (line 3)) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/devui->-r ../../../Installation/requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from aiohttp->agent-framework-azure-ai@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/azure-ai->-r ../../../Installation/requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from aiohttp->agent-framework-azure-ai@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/azure-ai->-r ../../../Installation/requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from aiohttp->agent-framework-azure-ai@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/azure-ai->-r ../../../Installation/requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from aiohttp->agent-framework-azure-ai@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/azure-ai->-r ../../../Installation/requirements.txt (line 2)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from aiohttp->agent-framework-azure-ai@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/azure-ai->-r ../../../Installation/requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/lokinfey/conda/envs/mafdev/lib/python3.12/site-packages (from aiohttp->agent-framework-azure-ai@ git+https://github.com/microsoft/agent-framework.git@main#subdirectory=python/packages/azure-ai->-r ../../../Installation/requirements.txt (line 2)) (1.22.0)

# %%
# 📦 Import Essential Libraries
# Core system and utility libraries for building AI agents

import os                      # Environment variable access for secure configuration
from random import randint     # Random number generation for destination selection

# 🔧 Environment configuration management
from dotenv import load_dotenv # Load API keys and settings from .env file

# %%
# 🤖 Import Microsoft Agent Framework Components
# Core classes for building intelligent conversational agents

from agent_framework import ChatAgent           # Main agent orchestrator class
from agent_framework.openai import OpenAIChatClient  # GitHub Models API client

# %%
# 🔧 Load Environment Configuration
# Initialize environment variables from .env file for secure API access
# Required: GITHUB_TOKEN, GITHUB_ENDPOINT, GITHUB_MODEL_ID
load_dotenv()
# Out:
# True

# %%
# 🎯 Define Agent Tool: Random Destination Generator
# This function becomes a callable tool that the agent can use dynamically

def get_random_destination() -> str:
    """
    🌍 Generate Random Travel Destination
    
    Provides the agent with the ability to suggest exciting vacation destinations
    when users need inspiration for their travel plans.
    
    Returns:
        str: A randomly selected destination from our curated global list
        
    Enterprise Note: In production, this could be enhanced with:
    - Database integration for dynamic destination management
    - Personalization based on user preferences and history
    - Real-time availability and pricing data integration
    """
    # 🗺️ Curated list of world-class vacation destinations
    # Each destination offers unique cultural, natural, or urban experiences
    destinations = [
        "Barcelona, Spain",        # Mediterranean culture & architecture
        "Paris, France",           # European elegance & romance
        "Berlin, Germany",         # Modern history & vibrant arts scene
        "Tokyo, Japan",            # Cutting-edge technology & tradition
        "Sydney, Australia",       # Iconic harbors & outdoor lifestyle
        "New York, USA",           # Urban energy & cultural diversity
        "Cairo, Egypt",            # Ancient history & archaeological wonders
        "Cape Town, South Africa", # Stunning landscapes & wine regions
        "Rio de Janeiro, Brazil",  # Beaches, mountains & carnival culture
        "Bali, Indonesia"          # Tropical paradise & spiritual retreats
    ]
    
    # 🎲 Return randomly selected destination for inspiring travel planning
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Initialize GitHub Models Client
# Create the API client that connects our agent to advanced AI capabilities
openai_chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # GitHub Models API endpoint
    api_key=os.environ.get("GITHUB_TOKEN"),        # Your authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # Model selection (e.g., gpt-4o-mini)
)

# %%
# 🤖 Create Your First AI Agent!
# This is where the magic happens - creating an intelligent travel planning assistant

agent = ChatAgent(
    chat_client=openai_chat_client,  # 🔗 AI model connection
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations.",  # 🎯 Agent personality and role
    tools=[get_random_destination]   # 🛠️ Available functions the agent can use
)

# %%
# 🚀 Test Your Agent - Request a Travel Plan
# Let's see your agent in action! It will automatically use the random destination tool
response = await agent.run("Plan me a day trip")

# %%
# 🔍 Explore the Response Structure
# Examine the complete response object to understand how agent conversations work
# This shows the internal structure, including messages and metadata
response

# %%
# 📖 Extract and Display Your Travel Plan
# Get the agent's response and display it in a user-friendly format

# Extract the agent's latest response message
last_message = response.messages[-1]
# Get the text content of the message
text_content = last_message.contents[0].text

# 🎉 Display your personalized travel itinerary!
print("✈️ Your AI-Generated Travel Plan:")
print("=" * 50)
print(text_content)
print("=" * 50)
print("🤖 Created by your AI Travel Agent using Microsoft Agent Framework!")
# Out:
# ✈️ Your AI-Generated Travel Plan:
# ==================================================
# Sure! To help plan your perfect day trip, could you please tell me:
# 1. Your starting location or nearby city?
# 2. Your interests (e.g., nature, history, food, adventure)?
# 3. Whether you prefer a relaxing day or a more active, packed schedule?
# 4. Any other preferences or restrictions (e.g., travel distance, budget)?
#
# If you'd like, I can also suggest a random destination to inspire your day trip. Would you like me to do that?
# ==================================================
# 🤖 Created by your AI Travel Agent using Microsoft Agent Framework!
